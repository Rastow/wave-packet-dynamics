# %%
import os

base_path = os.getcwd()
relative_file_path = "harmonic_oscillator"
file_name = "time.txt"
absolute_file_path = os.path.abspath(os.path.join(base_path, relative_file_path, file_name))
print(absolute_file_path)

with open(absolute_file_path, "r") as file:
    for i, line in enumerate(file):
        if i == 25:
            print(line)
        elif i == 29:
            print(line)
        elif i > 29:
            break
# Out:
# D:\Robert\Documents\PycharmProjects\wave-packet-dynamics\docs\source\notebooks\harmonic_oscillator\time.txt
# 250, 0.01250,
#
# 290, 0.01450,
